# %%
import pandas as pd

# %%
url = "https://www.espncricinfo.com/records/highest-career-batting-average-282910"

# %%
tables = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tables = pd.read_html(url)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
# ...

# %%
# !pip install lxml html5lib

# %%
tables = pd.read_html(url)

# %%
df=pd.read_csv("cricinfo.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df=df.rename(columns={'Mat':'Matches_played'}) #{'key':'value'}

# %%
df
# Out:
#                Player       Span  Matches_played  Inns  NO  Runs    HS    Ave  \
# 0    DG Bradman (AUS)  1928-1948              52    80  10  6996   334  99.94
# 1    PHKD Mendis (SL)  2022-2025              12    21   2  1184  182*  62.31
# 2      AC Voges (AUS)  2015-2016              20    31   7  1485  269*  61.87
# 3     RG Pollock (SA)  1963-1970              23    41   4  2256   274  60.97
# 4     GA Headley (WI)  1930-1954              22    40   4  2190  270*  60.83
# ..                ...        ...             ...   ...  ..   ...   ...    ...
# 57   KD Walters (AUS)  1965-1981              74   125  14  5357   250  48.26
# 58  GC Smith (ICC/SA)  2002-2014             117   205  13  9265   277  48.25
# 59  WH Ponsford (AUS)  1924-1934              29    48   4  2122   266  48.22
# 60    SJ McCabe (AUS)  1930-1938              39    62   5  2748   232  48.21
# 61   DR Jardine (ENG)  1928-1934              22    33   6  1296   127  48.00
#
# ...

# %%
#renaming multiple columns at a time

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Matches_played', 'Inns', 'NO', 'Runs', 'HS', 'Ave',
#        'BF', 'SR', '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df=df.rename(columns={'Inns':'innings','NO':'not_out','HS':'highest_score','Ave':'average','BF':'balls_faced','SR':'strike_rate'})

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s
# ...

# %%
df.isnull().any()
# Out:
# Player            False
# Span              False
# Matches_played    False
# innings           False
# not_out           False
# Runs              False
# highest_score     False
# average           False
# balls_faced       False
# strike_rate       False
# 100               False
# 50                False
# 0                 False
# 4s                False
# 6s                False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Matches_played', 'innings', 'not_out', 'Runs',
#        'highest_score', 'average', 'balls_faced', 'strike_rate', '100', '50',
#        '0', '4s', '6s'],
#       dtype='object')

# %%
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1      PHKD Mendis (SL)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       GA Headley (WI)
#             ...
# 57     KD Walters (AUS)
# 58    GC Smith (ICC/SA)
# 59    WH Ponsford (AUS)
# 60      SJ McCabe (AUS)
# 61     DR Jardine (ENG)
# Name: Player, Length: 62, dtype: object

# %%
duplicate_rows = df[df['Player'].isin(['AC Voges (AUS)','RG Pollock (SA)','GA Headley (WI)'])]

# %%
df = pd.concat([df,duplicate_rows], ignore_index=True)

# %%
df
# Out:
#               Player       Span  Matches_played  innings  not_out  Runs  \
# 0   DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1   PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2     AC Voges (AUS)  2015-2016              20       31        7  1485
# 3    RG Pollock (SA)  1963-1970              23       41        4  2256
# 4    GA Headley (WI)  1930-1954              22       40        4  2190
# ..               ...        ...             ...      ...      ...   ...
# 60   SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61  DR Jardine (ENG)  1928-1934              22       33        6  1296
# 62    AC Voges (AUS)  2015-2016              20       31        7  1485
# 63   RG Pollock (SA)  1963-1970              23       41        4  2256
# 64   GA Headley (WI)  1930-1954              22       40        4  2190
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62     True
# 63     True
# 64     True
# Length: 65, dtype: bool

# %%
df
# Out:
#               Player       Span  Matches_played  innings  not_out  Runs  \
# 0   DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1   PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2     AC Voges (AUS)  2015-2016              20       31        7  1485
# 3    RG Pollock (SA)  1963-1970              23       41        4  2256
# 4    GA Headley (WI)  1930-1954              22       40        4  2190
# ..               ...        ...             ...      ...      ...   ...
# 60   SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61  DR Jardine (ENG)  1928-1934              22       33        6  1296
# 62    AC Voges (AUS)  2015-2016              20       31        7  1485
# 63   RG Pollock (SA)  1963-1970              23       41        4  2256
# 64   GA Headley (WI)  1930-1954              22       40        4  2190
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s
# ...

# %%
df.dtypes
# Out:
# Player             object
# Span               object
# Matches_played      int64
# innings             int64
# not_out             int64
# Runs                int64
# highest_score      object
# average           float64
# balls_faced        object
# strike_rate        object
# 100                 int64
# 50                  int64
# 0                  object
# 4s                  int64
# 6s                  int64
# dtype: object

# %%
df
# Out:
#               Player       Span  Matches_played  innings  not_out  Runs  \
# 0   DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1   PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2     AC Voges (AUS)  2015-2016              20       31        7  1485
# 3    RG Pollock (SA)  1963-1970              23       41        4  2256
# 4    GA Headley (WI)  1930-1954              22       40        4  2190
# ..               ...        ...             ...      ...      ...   ...
# 60   SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61  DR Jardine (ENG)  1928-1934              22       33        6  1296
# 62    AC Voges (AUS)  2015-2016              20       31        7  1485
# 63   RG Pollock (SA)  1963-1970              23       41        4  2256
# 64   GA Headley (WI)  1930-1954              22       40        4  2190
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s
# ...

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\Administrator\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62     True
# 63     True
# 64     True
# Length: 65, dtype: bool

# %%
df.tail(3)
# Out:
#              Player       Span  Matches_played  innings  not_out  Runs  \
# 62   AC Voges (AUS)  2015-2016              20       31        7  1485
# 63  RG Pollock (SA)  1963-1970              23       41        4  2256
# 64  GA Headley (WI)  1930-1954              22       40        4  2190
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s
# 62          269*    61.87        2667       55.68    5   4  2  186   5
# 63           274    60.97       1707+       54.48    7  11  1  246  11
# 64          270*    60.83        416+          56   10   5  2  104   1

# %%
df[df['Player'].isin(['AC Voges (AUS)','RG Pollock (SA)','GA Headley (WI)'])]
# Out:
#              Player       Span  Matches_played  innings  not_out  Runs  \
# 2    AC Voges (AUS)  2015-2016              20       31        7  1485
# 3   RG Pollock (SA)  1963-1970              23       41        4  2256
# 4   GA Headley (WI)  1930-1954              22       40        4  2190
# 62   AC Voges (AUS)  2015-2016              20       31        7  1485
# 63  RG Pollock (SA)  1963-1970              23       41        4  2256
# 64  GA Headley (WI)  1930-1954              22       40        4  2190
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s
# 2           269*    61.87        2667       55.68    5   4  2  186   5
# 3            274    60.97       1707+       54.48    7  11  1  246  11
# 4           270*    60.83        416+          56   10   5  2  104   1
# 62          269*    61.87        2667       55.68    5   4  2  186   5
# 63           274    60.97       1707+       54.48    7  11  1  246  11
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s
# ...

# %%
#split method for splitting it (Span) into start and end date

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 57    1965
# 58    2002
# 59    1924
# 60    1930
# 61    1928
# Name: Span, Length: 62, dtype: object

# %%
df['start_year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13624\3240263256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_year']=df['Span'].str.split(pat='-').str[0]

# %%
df['start_year']
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 57    1965
# 58    2002
# 59    1924
# 60    1930
# 61    1928
# Name: start_year, Length: 62, dtype: object

# %%
df['end_year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13624\3495205318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end_year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          62 non-null     object
#  1   Span            62 non-null     object
#  2   Matches_played  62 non-null     int64
#  3   innings         62 non-null     int64
#  4   not_out         62 non-null     int64
#  5   Runs            62 non-null     int64
#  6   highest_score   62 non-null     object
#  7   average         62 non-null     float64
#  8   balls_faced     62 non-null     object
#  9   strike_rate     62 non-null     object
#  10  100             62 non-null     int64
#  11  50              62 non-null     int64
#  12  0               62 non-null     object
#  13  4s              62 non-null     int64
#  14  6s              62 non-null     int64
#  15  start_year      62 non-null     object
#  16  end_year        62 non-null     object
# ...

# %%
df['country1']=df['Player'].str.split(pat='(').str[1]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13624\1424915988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country1']=df['Player'].str.split(pat='(').str[1]

# %%
df['country1']=df['country1'].str.split(pat=')').str[0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13624\3446217031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country1']=df['country1'].str.split(pat=')').str[0]

# %%
df['country']=df['country'].str.split(pat=')').str[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ...

# %%
df

# %%
df

# %%
df['Player']

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df

# %%
df=df.drop(['Span'], axis=1)

# %%
df

# %%
df['highest_score']=df['highest_score'].str.split(pat='*').str[0]

# %%
df['highest_score']
# Out:
# 0      334
# 1     182*
# 2     269*
# 3      274
# 4     270*
#       ...
# 57     250
# 58     277
# 59     266
# 60     232
# 61     127
# Name: highest_score, Length: 62, dtype: object

# %%
df['balls_faced']=df['balls_faced'].str.split(pat='+').str[0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13624\3070048646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_faced']=df['balls_faced'].str.split(pat='+').str[0]

# %%
df['balls_faced']
# Out:
# 0      9800
# 1      1839
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: balls_faced, Length: 62, dtype: object

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df=df.drop(['country1'], axis=1)

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player          62 non-null     object
#  1   Span            62 non-null     object
#  2   Matches_played  62 non-null     int64
#  3   innings         62 non-null     int64
#  4   not_out         62 non-null     int64
#  5   Runs            62 non-null     int64
#  6   highest_score   62 non-null     object
#  7   average         62 non-null     float64
#  8   balls_faced     62 non-null     object
#  9   strike_rate     62 non-null     object
#  10  100             62 non-null     int64
#  11  50              62 non-null     int64
#  12  0               62 non-null     object
#  13  4s              62 non-null     int64
#  14  6s              62 non-null     int64
#  15  start_year      62 non-null     object
#  16  end_year        62 non-null     object
# ...

# %%
df.dtypes
# Out:
# Player             object
# Span               object
# Matches_played      int64
# innings             int64
# not_out             int64
# Runs                int64
# highest_score      object
# average           float64
# balls_faced        object
# strike_rate        object
# 100                 int64
# 50                  int64
# 0                  object
# 4s                  int64
# 6s                  int64
# start_year         object
# end_year           object
# dtype: object

# %%
df['highest_score']=df['highest_score'].astype('int') #for individual changes in data type
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['highest_score']=df['highest_score'].astype('int') #for individual changes in data type
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df=df.astype({'highest_score':'int','start_year':'int','end_year':'int'}) ##for individual changes in data type within data frame

# %%
df.columns

# %%
new_order = [
    'Player', 'start_year', 'end_year',     # Basic info
    'Matches_played', 'innings', 'not_out', # Match-related stats
    'Runs', 'highest_score', 'average', 'strike_rate', # Batting performance
    '100', '50', '0',                       # Milestones & ducks
    'balls_faced', '4s', '6s'               # Shot-specific & input stats
]

df = df[new_order]

# %%
df

# %%
df.columns

# %%
new_ord=['Player', 'start_year', 'end_year', 'innings','Matches_played',
       'not_out', 'Runs', 'highest_score', 'strike_rate','average', '100',
       '50', '0', 'balls_faced', '4s', '6s']

# %%
new_ord

# %%
df=df[new_ord]

# %%
df

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1      PHKD Mendis (SL)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       GA Headley (WI)
#             ...
# 57     KD Walters (AUS)
# 58    GC Smith (ICC/SA)
# 59    WH Ponsford (AUS)
# 60      SJ McCabe (AUS)
# 61     DR Jardine (ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Player'].str.split('(')
# Out:
# 0      [DG Bradman , AUS)]
# 1      [PHKD Mendis , SL)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 57     [KD Walters , AUS)]
# 58    [GC Smith , ICC/SA)]
# 59    [WH Ponsford , AUS)]
# 60      [SJ McCabe , AUS)]
# 61     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['country11']=df['Player'].str.split('(').str[1]

# %%
df['country11']=df['country11'].str.split(')').str[0]

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df2=df

# %%
df2
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df2.dropna()
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df2=pd.read_excel('Customer Call List.xlsx')

# %%
df2.isna().any()
# Out:
# CustomerID           False
# First_Name           False
# Last_Name             True
# Phone_Number          True
# Address              False
# Paying Customer      False
# Do_Not_Contact        True
# Not_Useful_Column    False
# dtype: bool

# %%
df2.shape
# Out:
# (21, 8)

# %%
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (15, 8)

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df['Player',''].str.lower()
# Out:
# 0      dg bradman (aus)
# 1      phkd mendis (sl)
# 2        ac voges (aus)
# 3       rg pollock (sa)
# 4       ga headley (wi)
#             ...
# 57     kd walters (aus)
# 58    gc smith (icc/sa)
# 59    wh ponsford (aus)
# 60      sj mccabe (aus)
# 61     dr jardine (eng)
# Name: Player, Length: 62, dtype: object

# %%
df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876|678|3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         15 non-null     int64
#  1   First_Name         15 non-null     object
#  2   Last_Name          15 non-null     object
#  3   Phone_Number       15 non-null     object
#  4   Address            15 non-null     object
#  5   Paying Customer    15 non-null     object
#  6   Do_Not_Contact     15 non-null     object
#  7   Not_Useful_Column  15 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 975.0+ bytes

# %%
df2
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='object')

# %%
df2=list(df2.columns)

# %%
df2
# Out:
# ['CustomerID',
#  'First_Name',
#  'Last_Name',
#  'Phone_Number',
#  'Address',
#  'Paying Customer',
#  'Do_Not_Contact',
#  'Not_Useful_Column']

# %%
df2['First_Name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df2['First_Name']
#
# TypeError: list indices must be integers or slices, not str

# %%
df2=pd.read_excel('Customer Call List.xlsx')

# %%
df[df['Player'] == 'PHKD Mendis (SL)']
# Out:
#              Player       Span  Matches_played  innings  not_out  Runs  \
# 1  PHKD Mendis (SL)  2022-2025              12       21        2  1184
#
#   highest_score  average balls_faced strike_rate  100  50  0   4s  6s  \
# 1          182*    62.31        1839       64.38    5   4  -  123  23
#
#   start_year end_year country11
# 1       2022     2025        SL

# %%
df
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52       80       10  6996
# 1    PHKD Mendis (SL)  2022-2025              12       21        2  1184
# 2      AC Voges (AUS)  2015-2016              20       31        7  1485
# 3     RG Pollock (SA)  1963-1970              23       41        4  2256
# 4     GA Headley (WI)  1930-1954              22       40        4  2190
# ..                ...        ...             ...      ...      ...   ...
# 57   KD Walters (AUS)  1965-1981              74      125       14  5357
# 58  GC Smith (ICC/SA)  2002-2014             117      205       13  9265
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
# 60    SJ McCabe (AUS)  1930-1938              39       62        5  2748
# 61   DR Jardine (ENG)  1928-1934              22       33        6  1296
#
#    highest_score  average balls_faced strike_rate  100  50   0    4s  6s  \
# ...

# %%
df[df['Player'] == 'WH Ponsford (AUS)']
# Out:
#                Player       Span  Matches_played  innings  not_out  Runs  \
# 59  WH Ponsford (AUS)  1924-1934              29       48        4  2122
#
#    highest_score  average balls_faced strike_rate  100  50  0   4s  6s  \
# 59           266    48.22        3118       44.77    7   6  1  119   0
#
#    start_year end_year country11
# 59       1924     1934       AUS

# %%
df2.describe()
# Out:
#         CustomerID
# count    21.000000
# mean   1010.952381
# std       6.127611
# min    1001.000000
# 25%    1006.000000
# 50%    1011.000000
# 75%    1016.000000
# max    1020.000000

# %%
df.describe()
# Out:
#        Matches_played     innings    not_out          Runs    average  \
# count       62.000000   62.000000  62.000000     62.000000  62.000000
# mean        78.693548  133.467742  13.919355   6332.580645  53.815484
# std         52.035482   88.593697  11.374833   4116.130956   7.187252
# min         12.000000   20.000000   1.000000    990.000000  48.000000
# 25%         23.250000   40.250000   5.000000   2206.500000  49.660000
# 50%         79.000000  131.500000  12.000000   6192.000000  51.950000
# 75%        117.750000  199.500000  19.000000   9156.750000  56.677500
# max        200.000000  329.000000  49.000000  15921.000000  99.940000
#
#              100         50           4s         6s
# count  62.000000  62.000000    62.000000  62.000000
# mean   19.080645  28.225806   641.741935  27.758065
# std    12.693484  19.111767   530.515182  27.469617
# min     1.000000   3.000000    37.000000   0.000000
# 25%     7.000000  10.000000   152.250000   5.000000
# ...

# %%
df['Span'].Str.split('-')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13624\2396198897.py in ?()
# ----> 1 df['Span'].Str.split('-')
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Str'
